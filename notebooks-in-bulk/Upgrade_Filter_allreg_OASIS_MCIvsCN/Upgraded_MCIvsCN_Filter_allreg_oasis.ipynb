# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import nibabel
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import tensorflow as tf
import cv2
from skimage.filters import unsharp_mask
from sklearn.utils import shuffle
from sklearn.utils.class_weight import compute_class_weight
from skimage.transform import resize
from dipy.align.imwarp import SymmetricDiffeomorphicRegistration
from dipy.align.metrics import CCMetric
from dipy.align.imaffine import AffineMap
from dipy.align import resample
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten
from tensorflow.keras.layers import Conv3D, AveragePooling3D, MaxPooling3D
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling3D, GlobalMaxPooling3D, Reshape
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import Callback

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import six
from math import ceil

# %%
def _bn_relu(input):
    """Helper to build a BN -> relu block (by @raghakot)."""
    norm = BatchNormalization(axis=CHANNEL_AXIS)(input)
    return Activation("relu")(norm)

def _conv_bn_relu3D(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        conv = Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(input)
        return _bn_relu(conv)

    return f

# %%
def _bn_relu_conv3d(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        activation = _bn_relu(input)
        return Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(activation)

    return f

def _shortcut3d(input, residual):
    stride_dim1 = ceil(input.shape[DIM1_AXIS] / residual.shape[DIM1_AXIS])
    stride_dim2 = ceil(input.shape[DIM2_AXIS] / residual.shape[DIM2_AXIS])
    stride_dim3 = ceil(input.shape[DIM3_AXIS] / residual.shape[DIM3_AXIS])
    equal_channels = residual.shape[CHANNEL_AXIS] == input.shape[CHANNEL_AXIS]

    shortcut = input
    if stride_dim1 > 1 or stride_dim2 > 1 or stride_dim3 > 1 or not equal_channels:
        shortcut = Conv3D(
            filters=residual.shape[CHANNEL_AXIS],
            kernel_size=(1, 1, 1),
            strides=(stride_dim1, stride_dim2, stride_dim3),
            kernel_initializer="he_normal",
            padding="valid",
            kernel_regularizer=l2(1e-4),
        )(input)
    return add([shortcut, residual])

# %%
def _conv_bn_relu3D(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        conv = Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(input)
        return _bn_relu(conv)

    return f

def _bn_relu_conv3d(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        activation = _bn_relu(input)
        return Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(activation)

    return f

# %%
def _shortcut3d(input, residual):
    stride_dim1 = ceil(input.shape[DIM1_AXIS] / residual.shape[DIM1_AXIS])
    stride_dim2 = ceil(input.shape[DIM2_AXIS] / residual.shape[DIM2_AXIS])
    stride_dim3 = ceil(input.shape[DIM3_AXIS] / residual.shape[DIM3_AXIS])
    equal_channels = residual.shape[CHANNEL_AXIS] == input.shape[CHANNEL_AXIS]

    shortcut = input
    if stride_dim1 > 1 or stride_dim2 > 1 or stride_dim3 > 1 or not equal_channels:
        shortcut = Conv3D(
            filters=residual.shape[CHANNEL_AXIS],
            kernel_size=(1, 1, 1),
            strides=(stride_dim1, stride_dim2, stride_dim3),
            kernel_initializer="he_normal",
            padding="valid",
            kernel_regularizer=l2(1e-4),
        )(input)
    return add([shortcut, residual])

def _residual_block_with_cbam(
    filters,
    kernel_regularizer,
    is_first_layer=False,
):
    def f(input):
        strides = (2, 2, 2) if not is_first_layer else (1, 1, 1)
        conv1 = _conv_bn_relu3D(
            filters=filters,
            kernel_size=(5, 5, 5),  # Changed kernel size
            strides=strides,
            kernel_regularizer=kernel_regularizer,
        )(input)
        
        conv2 = _conv_bn_relu3D(
            filters=filters,
            kernel_size=(5, 5, 5),  # Changed kernel size
            kernel_regularizer=kernel_regularizer,
        )(conv1)

        # CBAM module
        channel_avg_pool = GlobalAveragePooling3D()(conv2)
        channel_max_pool = GlobalMaxPooling3D()(conv2)
        channel_attention = add([Dense(filters // 2, activation='relu')(channel_avg_pool),
                                 Dense(filters // 2, activation='relu')(channel_max_pool)])
        channel_attention = Activation('sigmoid')(Dense(filters, activation='relu')(channel_attention))
        channel_attention = Reshape((1, 1, 1, filters))(channel_attention)
        channel_attention = multiply([conv2, channel_attention])

        spatial_attention = Conv3D(1, (1, 1, 1), activation='sigmoid', padding='same', kernel_initializer='he_normal')(conv2)
        attention = multiply([conv2, spatial_attention])

        conv2 = add([channel_attention, attention])
        
        return _shortcut3d(input, conv2)

    return f

# %%
def basic_block(
    filters,
    strides=(1, 1, 1),
    kernel_regularizer=l2(1e-4),
    is_first_block_of_first_layer=False,
):
    def f(input):
        if is_first_block_of_first_layer:
            conv1 = Conv3D(
                filters=filters,
                kernel_size=(5, 5, 5),  # Changed kernel size
                strides=strides,
                padding="same",
                kernel_initializer="he_normal",
                kernel_regularizer=kernel_regularizer,
            )(input)
        else:
            conv1 = _bn_relu_conv3d(
                filters=filters,
                kernel_size=(5, 5, 5),  # Changed kernel size
                strides=strides,
                kernel_regularizer=kernel_regularizer,
            )(input)

        residual = _bn_relu_conv3d(
            filters=filters,
            kernel_size=(5, 5, 5),  # Changed kernel size
            kernel_regularizer=kernel_regularizer,
        )(conv1)
        return _shortcut3d(input, residual)

    return f

def _handle_data_format():
    global DIM1_AXIS
    global DIM2_AXIS
    global DIM3_AXIS
    global CHANNEL_AXIS
    if K.image_data_format() == "channels_last":
        DIM1_AXIS = 1
        DIM2_AXIS = 2
        DIM3_AXIS = 3
        CHANNEL_AXIS = 4
    else:
        CHANNEL_AXIS = 1
        DIM1_AXIS = 2
        DIM2_AXIS = 3
        DIM3_AXIS = 4

def _get_block(identifier):
    if isinstance(identifier, six.string_types):
        res = globals().get(identifier)
        if not res:
            raise ValueError("Invalid {}".format(identifier))
        return res
    return identifier

class Resnet3DBuilder(object):
    """ResNet3D."""

    @staticmethod
    def build(input_shape, num_outputs, block_fn, repetitions, reg_factor):
        """Instantiate a vanilla ResNet3D keras model.

        # Arguments
            input_shape: Tuple of input shape in the format
            (conv_dim1, conv_dim2, conv_dim3, channels) if dim_ordering='tf'
            (filter, conv_dim1, conv_dim2, conv_dim3) if dim_ordering='th'
            num_outputs: The number of outputs at the final softmax layer
            block_fn: Unit block to use {'basic_block', 'bottlenack_block'}
            repetitions: Repetitions of unit blocks
        # Returns
            model: a 3D ResNet model that takes a 5D tensor (volumetric images
            in batch) as input and returns a 1D vector (prediction) as output.
        """
        _handle_data_format()
        if len(input_shape) != 4:
            raise ValueError(
                "Input shape should be a tuple "
                "(conv_dim1, conv_dim2, conv_dim3, channels) "
                "for tensorflow as backend or "
                "(channels, conv_dim1, conv_dim2, conv_dim3) "
                "for theano as backend"
            )

        block_fn = _get_block(block_fn)
        input = Input(shape=input_shape)
        # first conv
        conv1 = _conv_bn_relu3D(
            filters=128,  # Changed filter size
            kernel_size=(5, 5, 5),  # Changed kernel size
            strides=(2, 2, 2),
            kernel_regularizer=l2(reg_factor),
        )(input)
        pool1 = MaxPooling3D(pool_size=(3, 3, 3), strides=(2, 2, 2), padding="same")(
            conv1
        )

        # repeat blocks
        block = pool1
        filters = 128  # Changed filter size
        for i, r in enumerate(repetitions):
            block = _residual_block_with_cbam(
                filters=filters,
                kernel_regularizer=l2(reg_factor),
                is_first_layer=(i == 0),
            )(block)
            filters *= 2

        # last activation
        block_output = _bn_relu(block)

        # average pool and classification
        pool2 = AveragePooling3D(
            pool_size=(
                block.shape[DIM1_AXIS],
                block.shape[DIM2_AXIS],
                block.shape[DIM3_AXIS],
            ),
            strides=(1, 1, 1),
        )(block_output)
        flatten1 = Flatten()(pool2)
        if num_outputs > 1:
            dense = Dense(
                units=num_outputs,
                kernel_initializer="he_normal",
                activation="softmax",
                kernel_regularizer=l2(reg_factor),
            )(flatten1)
        else:
            dense = Dense(
                units=num_outputs,
                kernel_initializer="he_normal",
                activation="sigmoid",
                kernel_regularizer=l2(reg_factor),
            )(flatten1)

        model = Model(inputs=input, outputs=dense)
        return model

    @staticmethod
    def build_resnet_18(input_shape, num_outputs, reg_factor=1e-4):
        """Build resnet 18."""
        return Resnet3DBuilder.build(
            input_shape, num_outputs, basic_block, [2, 2, 2, 2], reg_factor=reg_factor
        )
    @staticmethod
    def build_resnet_34(input_shape, num_outputs, reg_factor=1e-4):
        """Build resnet 34."""
        return Resnet3DBuilder.build(
            input_shape, num_outputs, basic_block, [3, 4, 6, 3], reg_factor=reg_factor
        )

    @staticmethod
    def build_resnet_50(input_shape, num_outputs, reg_factor=1e-4):
        """Build resnet 50."""
        return Resnet3DBuilder.build(
            input_shape, num_outputs, basic_block, [3, 4, 6, 3], reg_factor=reg_factor
        )

    @staticmethod
    def build_resnet_101(input_shape, num_outputs, reg_factor=1e-4):
        """Build resnet 101."""
        return Resnet3DBuilder.build(
            input_shape, num_outputs, basic_block, [3, 4, 23, 3], reg_factor=reg_factor
        )

    @staticmethod
    def build_resnet_152(input_shape, num_outputs, reg_factor=1e-4):
        """Build resnet 152."""
        return Resnet3DBuilder.build(
            input_shape, num_outputs, basic_block, [3, 16, 36, 6], reg_factor=reg_factor
        )

# %%
# Testing the model
def apply_mask(aseg_image, brain_image, labels = [17, 53, 2, 7, 41, 46]):
    brain_data = aseg_image.get_fdata()
    aseg_data = aseg_image.get_fdata()
    origin_data = brain_image.get_fdata()
    
    brain_mask = np.zeros_like(aseg_data)
    for label in labels:
        brain_mask += np.where((aseg_data == label), 1, 0)

    new_image = origin_data * brain_mask
    
    return new_image

# %%
def enhance_slice(slice_data):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_slice = clahe.apply(slice_data.astype(np.uint8))

    return enhanced_slice

def enhance_image(img_data):
    enhanced_image = np.zeros_like(img_data)
    for i in range(img_data.shape[2]):
        enhanced_image[:, :, i] = enhance_slice(img_data[:, :, i])
    return enhanced_image

# %%
def sharpen_image(image, strength=1.0):
    sharpened_image = unsharp_mask(image, radius=1, amount=strength)
    return sharpened_image

def apply_nonlinear_registration(moving_image, fixed_image):
    metric = CCMetric(3)

    sdr = SymmetricDiffeomorphicRegistration(metric, [10, 10, 10], step_length=0.25, ss_sigma_factor=1.5)

    mapping = sdr.optimize(fixed_image, moving_image)

    warped_moving_image = mapping.transform(moving_image)

    return warped_moving_image

# %%
def image_fixed(image_type, target_shape):
    aseg_image = nibabel.load('/home/uiu/Documents/oasis_fastsurfer/dataset/AD/OAS1_0028_MR1_1')
    base_path = "/home/uiu/Project/adni-1-5t-filtered-preprocessed-quickseg-dataset/AD/OAS1_0028_MR1_1/mri/orig.mgz"
    origin_image =  nibabel.load(base_path)
    
    if (image_type=='nonroi') :
        aseg_image = aseg_image.get_fdata()
        origin_image = origin_image.get_fdata()
        
        mask = np.where(asg_img != 0, 1, 0)
        image = origin_image * mask
        image = enhance_image(image)
        image = resize(image, target_shape, anti_aliasing=True)
        image = sharpen_image(image)
        
        return image

# %%
from scipy.ndimage import rotate

# %%
def augment(image, rotation_range):
    rotation_angle = np.random.uniform(-rotation_range, rotation_range)
    rotated_image = rotate(image, rotation_angle, reshape=False)
    
    return rotated_image



def image_load_nonRoi(image_path, target_shape, type_dt=''):
    asg_img = nibabel.load(image_path).get_fdata()
    
    origin_path = "/".join(image_path.split('/')[:-1]) + "/orig.mgz"
    origin_image = nibabel.load(origin_path).get_fdata()
    mask = np.where(asg_img != 0, 1, 0)
    
    image = origin_image * mask
    image = resize(image, target_shape, anti_aliasing=True)
    image = enhance_image(image)
    image = sharpen_image(image)

    
    if type_dt=='train':
        image = augment(image, 50)
        
    return image

# %%
def data_generator(paths, labels, batch_size, target_shape, image_type, type_dt=''):
    while True:
        for i in range(0, len(paths), batch_size):
            batch_paths = paths[i:i+batch_size]
            batch_labels = labels[i:i+batch_size]
            batch_images = []
            
    
            if image_type == 'nonroi':
                batch_images = [image_load_nonRoi(image, target_shape, type_dt) for image in batch_paths]

            batch_images = np.stack([batch_images] * 1, axis=-1)

            batch_labels = to_categorical(batch_labels, num_classes=2)
            yield np.array(batch_images), batch_labels
base_dir = '/home/uiu/Documents/oasis_fastsurfer/dataset'
ad = os.path.join(base_dir, 'AD')
mci = os.path.join(base_dir, 'MCI')
cn = os.path.join(base_dir, 'CN')
# original shape (257, 257, 257)

ad_images= []
mci_images = []
cn_images = []

for subject_dir in os.listdir(ad):
    mri_path = os.path.join(ad, subject_dir, 'mri', 'aparc.DKTatlas+aseg.deep.mgz')
    if not (len(os.listdir(os.path.join(ad, subject_dir, 'mri'))) < 6):
        ad_images.append(mri_path)
        
for subject_dir in os.listdir(mci):
    mri_path = os.path.join(mci, subject_dir, 'mri', 'aparc.DKTatlas+aseg.deep.mgz')
    
    if not (len(os.listdir(os.path.join(mci, subject_dir, 'mri'))) < 6):
        mci_images.append(mri_path)
        
for subject_dir in os.listdir(cn):
    mri_path = os.path.join(cn, subject_dir, 'mri', 'aparc.DKTatlas+aseg.deep.mgz')
    if not (len(os.listdir(os.path.join(cn, subject_dir, 'mri'))) < 6):
        cn_images.append(mri_path)


image_path = mci_images + cn_images + cn_images[:len(mci_images)-len(cn_images)]
labels = [0] * len(mci_images) + [1] * len(cn_images) + [1] * len(cn_images[:len(mci_images)-len(cn_images)])
train_paths, test_paths, train_labels, test_labels = train_test_split(image_path, labels, test_size = 0.2, random_state=42)

class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
train_paths = np.array(train_paths)
train_labels = np.array(train_labels)
test_paths = np.array(test_paths)
test_labels = np.array(test_labels)

train_paths, train_labels = shuffle(train_paths, train_labels, random_state=42)
test_paths, test_labels = shuffle(test_paths, test_labels, random_state=42)

target_shape = (100, 100, 100)
batch_size = 10
selection_type = 'nonroi'
train_dataset = data_generator(train_paths, train_labels, batch_size, target_shape, 
                               image_type=selection_type, 
                               type_dt='train'
                              )

test_dataset = data_generator(test_paths, test_labels, batch_size, target_shape, 
                              image_type=selection_type
                             )
len(test_paths), len(train_labels), class_weights
# Out:
# (369, 1472, array([3.33031674, 0.58832934]))

# %%
from tensorflow.keras.optimizers import Adam

# %%
classes = 2
image_shape = (*target_shape, 1)
model = Resnet3DBuilder.build_resnet_152(input_shape = image_shape, num_outputs=classes)
    
model.compile(
  optimizer=Adam(0.000001), 
  loss='binary_crossentropy', 
  metrics=['accuracy', 'Recall', 'AUC', 'Precision']
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 10 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 50, 50, 50, 1 16128       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 50, 50, 1 512         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 50, 50, 50, 1 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 25, 25, 25, 1 0           activation[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 25, 25, 25, 1 2048128     max_pooling3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 25, 25, 25, 1 512         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 25, 25, 25, 1 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 25, 25, 25, 1 2048128     activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 25, 1 512         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 25, 25, 25, 1 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d (Globa (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d (GlobalMax (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        global_average_pooling3d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        global_max_pooling3d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64)           0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          8320        add[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1, 128) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 25, 25, 25, 1 129         activation_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 25, 25, 25, 1 0           activation_2[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 25, 25, 25, 1 0           activation_2[0][0]
#                                                                  conv3d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 25, 25, 25, 1 0           multiply[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 25, 25, 25, 1 0           max_pooling3d[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 13, 13, 13, 2 4096256     add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 13, 13, 13, 2 1024        conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 13, 13, 13, 2 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 13, 13, 13, 2 8192256     activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 13, 13, 13, 2 1024        conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 13, 13, 13, 2 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_1 (Glo (None, 256)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_1 (GlobalM (None, 256)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          32896       global_average_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          32896       global_max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128)          0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          33024       add_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 1, 256) 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 13, 13, 13, 1 257         activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 13, 13, 13, 2 0           activation_5[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 13, 13, 13, 2 0           activation_5[0][0]
#                                                                  conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 13, 13, 13, 2 33024       add_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 13, 13, 13, 2 0           multiply_2[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 13, 13, 13, 2 0           conv3d_7[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 7, 7, 7, 512) 16384512    add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 7, 7, 7, 512) 2048        conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 7, 512) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 7, 7, 7, 512) 32768512    activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 7, 512) 2048        conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 7, 512) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_2 (Glo (None, 512)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_2 (GlobalM (None, 512)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      global_average_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          131328      global_max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256)          0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          131584      add_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 1, 512) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 7, 7, 7, 1)   513         activation_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 7, 7, 7, 512) 0           activation_8[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 7, 7, 7, 512) 0           activation_8[0][0]
#                                                                  conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 7, 7, 7, 512) 131584      add_5[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 7, 512) 0           multiply_4[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 7, 512) 0           conv3d_11[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, 4, 4, 1024 65537024    add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 4, 1024 4096        conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 4, 1024 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 4, 4, 4, 1024 131073024   activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 4, 1024 4096        conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 4, 1024 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_3 (Glo (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_3 (GlobalM (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          524800      global_average_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 512)          524800      global_max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 512)          0           dense_9[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1024)         525312      add_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1024)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 1, 1024 0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 4, 4, 4, 1)   1025        activation_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 4, 4, 4, 1024 0           activation_11[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 4, 4, 4, 1024 0           activation_11[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 4, 4, 4, 1024 525312      add_8[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 4, 1024 0           multiply_6[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 4, 1024 0           conv3d_15[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 4, 1024 4096        add_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 4, 1024 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling3d (AveragePooli (None, 1, 1, 1, 1024 0           activation_13[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling3d[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            2050        flatten[0][0]
# ==================================================================================================
# Total params: 264,970,630
# Trainable params: 264,960,646
# Non-trainable params: 9,984
# __________________________________________________________________________________________________

# %%
# num_epoch = 50
# history = model.fit(
#     train_dataset,
#     epochs = num_epoch,
#     steps_per_epoch = len(train_paths) // batch_size,
#     validation_data = test_dataset,
#     validation_steps= len(test_paths) // batch_size,
# )

# %%
# model.save("CBAM_UpgradedFilter_CompleteReg_IJK_oasis.h5")

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model_checkpoint = ModelCheckpoint('CBAM_UpgradedFilter_CompleteReg_MCIvsCN_oasis.h5', monitor='val_accuracy', mode='max', save_best_only=True)

num_epoch = 50
history = model.fit(
    train_dataset,
    epochs=num_epoch,
    steps_per_epoch=len(train_paths) // batch_size,
    validation_data=test_dataset,
    validation_steps=len(test_paths) // batch_size,
    callbacks=[model_checkpoint]  
)
# Out:
# Epoch 1/50
# 147/147 [==============================] - 1509s 10s/step - loss: 1.7160 - accuracy: 0.8286 - recall: 0.8286 - auc: 0.8465 - precision: 0.8286 - val_loss: 1.6724 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9208 - val_precision: 0.8639
# Epoch 2/50
# 147/147 [==============================] - 1497s 10s/step - loss: 1.6117 - accuracy: 0.8313 - recall: 0.8313 - auc: 0.8955 - precision: 0.8313 - val_loss: 1.6755 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9324 - val_precision: 0.8639
# Epoch 3/50
# 147/147 [==============================] - 1489s 10s/step - loss: 1.5761 - accuracy: 0.8302 - recall: 0.8302 - auc: 0.9149 - precision: 0.8302 - val_loss: 1.7566 - val_accuracy: 0.7639 - val_recall: 0.7639 - val_auc: 0.8040 - val_precision: 0.7639
# Epoch 4/50
# 147/147 [==============================] - 1482s 10s/step - loss: 1.5323 - accuracy: 0.8300 - recall: 0.8300 - auc: 0.9318 - precision: 0.8300 - val_loss: 1.6074 - val_accuracy: 0.8111 - val_recall: 0.8111 - val_auc: 0.9156 - val_precision: 0.8111
# Epoch 5/50
# 147/147 [==============================] - 1467s 10s/step - loss: 1.5024 - accuracy: 0.8286 - recall: 0.8286 - auc: 0.9326 - precision: 0.8286 - val_loss: 1.4875 - val_accuracy: 0.8583 - val_recall: 0.8583 - val_auc: 0.9509 - val_precision: 0.8583
# Epoch 6/50
# 147/147 [==============================] - 1466s 10s/step - loss: 1.4788 - accuracy: 0.8468 - recall: 0.8468 - auc: 0.9396 - precision: 0.8468 - val_loss: 1.4582 - val_accuracy: 0.8667 - val_recall: 0.8667 - val_auc: 0.9549 - val_precision: 0.8667
# Epoch 7/50
# 147/147 [==============================] - 1458s 10s/step - loss: 1.4684 - accuracy: 0.8492 - recall: 0.8492 - auc: 0.9407 - precision: 0.8492 - val_loss: 1.4293 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9565 - val_precision: 0.8639
# Epoch 8/50
# 147/147 [==============================] - 1450s 10s/step - loss: 1.4553 - accuracy: 0.8461 - recall: 0.8461 - auc: 0.9441 - precision: 0.8461 - val_loss: 1.4235 - val_accuracy: 0.8750 - val_recall: 0.8750 - val_auc: 0.9579 - val_precision: 0.8750
# Epoch 9/50
# 147/147 [==============================] - 1433s 10s/step - loss: 1.4442 - accuracy: 0.8490 - recall: 0.8490 - auc: 0.9484 - precision: 0.8490 - val_loss: 1.4176 - val_accuracy: 0.8667 - val_recall: 0.8667 - val_auc: 0.9572 - val_precision: 0.8667
# Epoch 10/50
# 147/147 [==============================] - 1444s 10s/step - loss: 1.4415 - accuracy: 0.8517 - recall: 0.8517 - auc: 0.9469 - precision: 0.8517 - val_loss: 1.4542 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9442 - val_precision: 0.8639
# Epoch 11/50
# 147/147 [==============================] - 1422s 10s/step - loss: 1.4296 - accuracy: 0.8601 - recall: 0.8601 - auc: 0.9524 - precision: 0.8601 - val_loss: 1.4248 - val_accuracy: 0.8611 - val_recall: 0.8611 - val_auc: 0.9607 - val_precision: 0.8611
# Epoch 12/50
# 147/147 [==============================] - 1429s 10s/step - loss: 1.4240 - accuracy: 0.8607 - recall: 0.8607 - auc: 0.9525 - precision: 0.8607 - val_loss: 1.4088 - val_accuracy: 0.8722 - val_recall: 0.8722 - val_auc: 0.9587 - val_precision: 0.8722
# Epoch 13/50
# 147/147 [==============================] - 1422s 10s/step - loss: 1.4137 - accuracy: 0.8688 - recall: 0.8688 - auc: 0.9570 - precision: 0.8688 - val_loss: 1.4553 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9430 - val_precision: 0.8639
# Epoch 14/50
# 147/147 [==============================] - 1422s 10s/step - loss: 1.4265 - accuracy: 0.8477 - recall: 0.8477 - auc: 0.9484 - precision: 0.8477 - val_loss: 1.4143 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.9599 - val_precision: 0.8694
# Epoch 15/50
# 147/147 [==============================] - 1424s 10s/step - loss: 1.4115 - accuracy: 0.8716 - recall: 0.8716 - auc: 0.9566 - precision: 0.8716 - val_loss: 1.3942 - val_accuracy: 0.8778 - val_recall: 0.8778 - val_auc: 0.9623 - val_precision: 0.8778
# Epoch 16/50
# 147/147 [==============================] - 1420s 10s/step - loss: 1.3979 - accuracy: 0.8794 - recall: 0.8794 - auc: 0.9618 - precision: 0.8794 - val_loss: 1.4081 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.9609 - val_precision: 0.8694
# Epoch 17/50
# 147/147 [==============================] - 1398s 10s/step - loss: 1.3878 - accuracy: 0.8928 - recall: 0.8928 - auc: 0.9638 - precision: 0.8928 - val_loss: 1.4188 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.9574 - val_precision: 0.8694
# Epoch 18/50
# 147/147 [==============================] - 1419s 10s/step - loss: 1.3680 - accuracy: 0.9065 - recall: 0.9065 - auc: 0.9706 - precision: 0.9065 - val_loss: 1.4735 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9417 - val_precision: 0.8639
# Epoch 19/50
# 147/147 [==============================] - 1416s 10s/step - loss: 1.3670 - accuracy: 0.9020 - recall: 0.9020 - auc: 0.9712 - precision: 0.9020 - val_loss: 1.5429 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8970 - val_precision: 0.8639
# Epoch 20/50
# 147/147 [==============================] - 1431s 10s/step - loss: 1.3566 - accuracy: 0.9154 - recall: 0.9154 - auc: 0.9741 - precision: 0.9154 - val_loss: 1.4266 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.9500 - val_precision: 0.8694
# Epoch 21/50
# 147/147 [==============================] - 1436s 10s/step - loss: 1.3504 - accuracy: 0.9090 - recall: 0.9090 - auc: 0.9765 - precision: 0.9090 - val_loss: 1.5358 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9020 - val_precision: 0.8639
# Epoch 22/50
# 147/147 [==============================] - 1390s 10s/step - loss: 1.3402 - accuracy: 0.9228 - recall: 0.9228 - auc: 0.9791 - precision: 0.9228 - val_loss: 1.5946 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8847 - val_precision: 0.8639
# Epoch 23/50
# 147/147 [==============================] - 1369s 9s/step - loss: 1.3234 - accuracy: 0.9242 - recall: 0.9242 - auc: 0.9831 - precision: 0.9242 - val_loss: 1.6217 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8803 - val_precision: 0.8639
# Epoch 24/50
# 147/147 [==============================] - 1358s 9s/step - loss: 1.3121 - accuracy: 0.9358 - recall: 0.9358 - auc: 0.9858 - precision: 0.9358 - val_loss: 1.7490 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 25/50
# 147/147 [==============================] - 1368s 9s/step - loss: 1.3196 - accuracy: 0.9340 - recall: 0.9340 - auc: 0.9822 - precision: 0.9340 - val_loss: 1.6921 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8735 - val_precision: 0.8639
# Epoch 26/50
# 147/147 [==============================] - 1368s 9s/step - loss: 1.3162 - accuracy: 0.9289 - recall: 0.9289 - auc: 0.9816 - precision: 0.9289 - val_loss: 1.6201 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8803 - val_precision: 0.8639
# Epoch 27/50
# 147/147 [==============================] - 1368s 9s/step - loss: 1.3125 - accuracy: 0.9387 - recall: 0.9387 - auc: 0.9785 - precision: 0.9387 - val_loss: 1.7458 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 28/50
# 147/147 [==============================] - 1371s 9s/step - loss: 1.3014 - accuracy: 0.9353 - recall: 0.9353 - auc: 0.9811 - precision: 0.9353 - val_loss: 1.6099 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8852 - val_precision: 0.8639
# Epoch 29/50
# 147/147 [==============================] - 1355s 9s/step - loss: 1.2949 - accuracy: 0.9428 - recall: 0.9428 - auc: 0.9861 - precision: 0.9428 - val_loss: 1.5434 - val_accuracy: 0.8667 - val_recall: 0.8667 - val_auc: 0.9014 - val_precision: 0.8667
# Epoch 30/50
# 147/147 [==============================] - 1357s 9s/step - loss: 1.2776 - accuracy: 0.9490 - recall: 0.9490 - auc: 0.9874 - precision: 0.9490 - val_loss: 1.4355 - val_accuracy: 0.8806 - val_recall: 0.8806 - val_auc: 0.9373 - val_precision: 0.8806
# Epoch 31/50
# 147/147 [==============================] - 1453s 10s/step - loss: 1.2680 - accuracy: 0.9562 - recall: 0.9562 - auc: 0.9899 - precision: 0.9562 - val_loss: 1.7199 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8663 - val_precision: 0.8639
# Epoch 32/50
# 147/147 [==============================] - 1437s 10s/step - loss: 1.2537 - accuracy: 0.9612 - recall: 0.9612 - auc: 0.9927 - precision: 0.9612 - val_loss: 1.4233 - val_accuracy: 0.8861 - val_recall: 0.8861 - val_auc: 0.9383 - val_precision: 0.8861
# Epoch 33/50
# 147/147 [==============================] - 1452s 10s/step - loss: 1.2437 - accuracy: 0.9659 - recall: 0.9659 - auc: 0.9923 - precision: 0.9659 - val_loss: 1.4077 - val_accuracy: 0.8917 - val_recall: 0.8917 - val_auc: 0.9482 - val_precision: 0.8917
# Epoch 34/50
# 147/147 [==============================] - 1412s 10s/step - loss: 1.2368 - accuracy: 0.9687 - recall: 0.9687 - auc: 0.9935 - precision: 0.9687 - val_loss: 1.3411 - val_accuracy: 0.9139 - val_recall: 0.9139 - val_auc: 0.9654 - val_precision: 0.9139
# Epoch 35/50
# 147/147 [==============================] - 1407s 10s/step - loss: 1.2413 - accuracy: 0.9583 - recall: 0.9583 - auc: 0.9932 - precision: 0.9583 - val_loss: 1.2499 - val_accuracy: 0.9528 - val_recall: 0.9528 - val_auc: 0.9902 - val_precision: 0.9528
# Epoch 36/50
# 147/147 [==============================] - 1424s 10s/step - loss: 1.2240 - accuracy: 0.9722 - recall: 0.9722 - auc: 0.9953 - precision: 0.9722 - val_loss: 1.2707 - val_accuracy: 0.9444 - val_recall: 0.9444 - val_auc: 0.9904 - val_precision: 0.9444
# Epoch 37/50
# 147/147 [==============================] - 1401s 10s/step - loss: 1.2255 - accuracy: 0.9689 - recall: 0.9689 - auc: 0.9930 - precision: 0.9689 - val_loss: 1.3697 - val_accuracy: 0.8972 - val_recall: 0.8972 - val_auc: 0.9500 - val_precision: 0.8972
# Epoch 38/50
# 147/147 [==============================] - 1403s 10s/step - loss: 1.2219 - accuracy: 0.9685 - recall: 0.9685 - auc: 0.9960 - precision: 0.9685 - val_loss: 1.5952 - val_accuracy: 0.7861 - val_recall: 0.7861 - val_auc: 0.8578 - val_precision: 0.7861
# Epoch 39/50
# 147/147 [==============================] - 1404s 10s/step - loss: 1.2102 - accuracy: 0.9706 - recall: 0.9706 - auc: 0.9973 - precision: 0.9706 - val_loss: 1.7501 - val_accuracy: 0.7417 - val_recall: 0.7417 - val_auc: 0.7906 - val_precision: 0.7417
# Epoch 40/50
# 147/147 [==============================] - 1406s 10s/step - loss: 1.2129 - accuracy: 0.9687 - recall: 0.9687 - auc: 0.9948 - precision: 0.9687 - val_loss: 2.7878 - val_accuracy: 0.4028 - val_recall: 0.4028 - val_auc: 0.4051 - val_precision: 0.4028
# Epoch 41/50
# 147/147 [==============================] - 1425s 10s/step - loss: 1.1972 - accuracy: 0.9816 - recall: 0.9816 - auc: 0.9971 - precision: 0.9816 - val_loss: 1.2965 - val_accuracy: 0.9472 - val_recall: 0.9472 - val_auc: 0.9796 - val_precision: 0.9472
# Epoch 42/50
# 147/147 [==============================] - 1404s 10s/step - loss: 1.2009 - accuracy: 0.9773 - recall: 0.9773 - auc: 0.9958 - precision: 0.9773 - val_loss: 2.9453 - val_accuracy: 0.3889 - val_recall: 0.3889 - val_auc: 0.3773 - val_precision: 0.3889
# Epoch 43/50
# 147/147 [==============================] - 1406s 10s/step - loss: 1.1955 - accuracy: 0.9801 - recall: 0.9801 - auc: 0.9969 - precision: 0.9801 - val_loss: 1.2108 - val_accuracy: 0.9750 - val_recall: 0.9750 - val_auc: 0.9951 - val_precision: 0.9750
# Epoch 44/50
# 147/147 [==============================] - 1434s 10s/step - loss: 1.1909 - accuracy: 0.9797 - recall: 0.9797 - auc: 0.9977 - precision: 0.9797 - val_loss: 1.1903 - val_accuracy: 0.9861 - val_recall: 0.9861 - val_auc: 0.9985 - val_precision: 0.9861
# Epoch 45/50
# 147/147 [==============================] - 1422s 10s/step - loss: 1.1801 - accuracy: 0.9848 - recall: 0.9848 - auc: 0.9990 - precision: 0.9848 - val_loss: 2.4173 - val_accuracy: 0.5417 - val_recall: 0.5417 - val_auc: 0.5597 - val_precision: 0.5417
# Epoch 46/50
# 147/147 [==============================] - 1435s 10s/step - loss: 1.1770 - accuracy: 0.9887 - recall: 0.9887 - auc: 0.9988 - precision: 0.9887 - val_loss: 2.7625 - val_accuracy: 0.4056 - val_recall: 0.4056 - val_auc: 0.4054 - val_precision: 0.4056
# Epoch 47/50
# 147/147 [==============================] - 1416s 10s/step - loss: 1.1759 - accuracy: 0.9848 - recall: 0.9848 - auc: 0.9981 - precision: 0.9848 - val_loss: 1.3365 - val_accuracy: 0.9167 - val_recall: 0.9167 - val_auc: 0.9681 - val_precision: 0.9167
# Epoch 48/50
# 147/147 [==============================] - 1421s 10s/step - loss: 1.1720 - accuracy: 0.9825 - recall: 0.9825 - auc: 0.9987 - precision: 0.9825 - val_loss: 2.1454 - val_accuracy: 0.5639 - val_recall: 0.5639 - val_auc: 0.6143 - val_precision: 0.5639
# Epoch 49/50
# 147/147 [==============================] - 1414s 10s/step - loss: 1.1706 - accuracy: 0.9858 - recall: 0.9858 - auc: 0.9982 - precision: 0.9858 - val_loss: 2.0251 - val_accuracy: 0.6472 - val_recall: 0.6472 - val_auc: 0.6824 - val_precision: 0.6472
# Epoch 50/50
# 147/147 [==============================] - 1414s 10s/step - loss: 1.1724 - accuracy: 0.9802 - recall: 0.9802 - auc: 0.9975 - precision: 0.9802 - val_loss: 1.3581 - val_accuracy: 0.9028 - val_recall: 0.9028 - val_auc: 0.9582 - val_precision: 0.9028

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('CBAM_UpgradedFilter_CompleteReg_IJK_oasis')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig("CBAM_UpgradedFilter_CompleteReg_IJK_100_Epoch.png")

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model('CBAM_UpgradedFilter_CompleteReg_MCIvsCN_oasis.h5')

# %%
# Load the best model and evaluate on test data
saved_model = tf.keras.models.load_model('CBAM_UpgradedFilter_CompleteReg_MCIvsCN_oasis.h5')
test_accuracy = saved_model.evaluate(
    test_dataset,
    steps=len(test_paths) // batch_size,
    verbose=1
)
print("Test Accuracy:", test_accuracy)
# Out:
# 36/36 [==============================] - 260s 7s/step - loss: 1.1903 - accuracy: 0.9861 - recall: 0.9861 - auc: 0.9985 - precision: 0.9861
# Test Accuracy: [1.1903125047683716, 0.9861111044883728, 0.9861111044883728, 0.99849534034729, 0.9861111044883728]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
# Load the saved model
saved_model = tf.keras.models.load_model('CBAM_UpgradedFilter_CompleteReg_MCIvsCN_oasis.h5')

# %%
predictions = saved_model.predict(test_dataset, steps=len(test_paths) // batch_size)
predicted_labels = np.argmax(predictions, axis=1)


conf_matrix = confusion_matrix(test_labels[:len(predicted_labels)], predicted_labels)


plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', 
            xticklabels=['CN', 'MCI'], yticklabels=['CN', 'MCI'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('OASIS1-MCIvsCN: all region')
plt.savefig('confusion_matrix_allreg.png')


plt.show()
