# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import nibabel
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import tensorflow as tf
import cv2
from skimage.filters import unsharp_mask
from sklearn.utils import shuffle
from sklearn.utils.class_weight import compute_class_weight
from skimage.transform import resize
from dipy.align.imwarp import SymmetricDiffeomorphicRegistration
from dipy.align.metrics import CCMetric
from dipy.align.imaffine import AffineMap
from dipy.align import resample
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten
from tensorflow.keras.layers import Conv3D, AveragePooling3D, MaxPooling3D
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling3D, GlobalMaxPooling3D, Reshape
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import Callback

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import six
from math import ceil

# %%
def _bn_relu(input):
    """Helper to build a BN -> relu block (by @raghakot)."""
    norm = BatchNormalization(axis=CHANNEL_AXIS)(input)
    return Activation("relu")(norm)

def _conv_bn_relu3D(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        conv = Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(input)
        return _bn_relu(conv)

    return f

# %%
def _bn_relu_conv3d(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        activation = _bn_relu(input)
        return Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(activation)

    return f

def _shortcut3d(input, residual):
    stride_dim1 = ceil(input.shape[DIM1_AXIS] / residual.shape[DIM1_AXIS])
    stride_dim2 = ceil(input.shape[DIM2_AXIS] / residual.shape[DIM2_AXIS])
    stride_dim3 = ceil(input.shape[DIM3_AXIS] / residual.shape[DIM3_AXIS])
    equal_channels = residual.shape[CHANNEL_AXIS] == input.shape[CHANNEL_AXIS]

    shortcut = input
    if stride_dim1 > 1 or stride_dim2 > 1 or stride_dim3 > 1 or not equal_channels:
        shortcut = Conv3D(
            filters=residual.shape[CHANNEL_AXIS],
            kernel_size=(1, 1, 1),
            strides=(stride_dim1, stride_dim2, stride_dim3),
            kernel_initializer="he_normal",
            padding="valid",
            kernel_regularizer=l2(1e-4),
        )(input)
    return add([shortcut, residual])

# %%
def _conv_bn_relu3D(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        conv = Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(input)
        return _bn_relu(conv)

    return f

def _bn_relu_conv3d(**conv_params):
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))

    def f(input):
        activation = _bn_relu(input)
        return Conv3D(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            kernel_initializer=kernel_initializer,
            padding=padding,
            kernel_regularizer=kernel_regularizer,
        )(activation)

    return f

# %%
def _shortcut3d(input, residual):
    stride_dim1 = ceil(input.shape[DIM1_AXIS] / residual.shape[DIM1_AXIS])
    stride_dim2 = ceil(input.shape[DIM2_AXIS] / residual.shape[DIM2_AXIS])
    stride_dim3 = ceil(input.shape[DIM3_AXIS] / residual.shape[DIM3_AXIS])
    equal_channels = residual.shape[CHANNEL_AXIS] == input.shape[CHANNEL_AXIS]

    shortcut = input
    if stride_dim1 > 1 or stride_dim2 > 1 or stride_dim3 > 1 or not equal_channels:
        shortcut = Conv3D(
            filters=residual.shape[CHANNEL_AXIS],
            kernel_size=(1, 1, 1),
            strides=(stride_dim1, stride_dim2, stride_dim3),
            kernel_initializer="he_normal",
            padding="valid",
            kernel_regularizer=l2(1e-4),
        )(input)
    return add([shortcut, residual])

def _residual_block_with_cbam(
    filters,
    kernel_regularizer,
    is_first_layer=False,
):
    def f(input):
        strides = (2, 2, 2) if not is_first_layer else (1, 1, 1)
        conv1 = _conv_bn_relu3D(
            filters=filters,
            kernel_size=(5, 5, 5),  # Changed kernel size
            strides=strides,
            kernel_regularizer=kernel_regularizer,
        )(input)
        
        conv2 = _conv_bn_relu3D(
            filters=filters,
            kernel_size=(5, 5, 5),  # Changed kernel size
            kernel_regularizer=kernel_regularizer,
        )(conv1)

        # CBAM module
        channel_avg_pool = GlobalAveragePooling3D()(conv2)
        channel_max_pool = GlobalMaxPooling3D()(conv2)
        channel_attention = add([Dense(filters // 2, activation='relu')(channel_avg_pool),
                                 Dense(filters // 2, activation='relu')(channel_max_pool)])
        channel_attention = Activation('sigmoid')(Dense(filters, activation='relu')(channel_attention))
        channel_attention = Reshape((1, 1, 1, filters))(channel_attention)
        channel_attention = multiply([conv2, channel_attention])

        spatial_attention = Conv3D(1, (1, 1, 1), activation='sigmoid', padding='same', kernel_initializer='he_normal')(conv2)
        attention = multiply([conv2, spatial_attention])

        conv2 = add([channel_attention, attention])
        
        return _shortcut3d(input, conv2)

    return f

# %%
def basic_block(
    filters,
    strides=(1, 1, 1),
    kernel_regularizer=l2(1e-4),
    is_first_block_of_first_layer=False,
):
    def f(input):
        if is_first_block_of_first_layer:
            conv1 = Conv3D(
                filters=filters,
                kernel_size=(5, 5, 5),  # Changed kernel size
                strides=strides,
                padding="same",
                kernel_initializer="he_normal",
                kernel_regularizer=kernel_regularizer,
            )(input)
        else:
            conv1 = _bn_relu_conv3d(
                filters=filters,
                kernel_size=(5, 5, 5),  # Changed kernel size
                strides=strides,
                kernel_regularizer=kernel_regularizer,
            )(input)

        residual = _bn_relu_conv3d(
            filters=filters,
            kernel_size=(5, 5, 5),  # Changed kernel size
            kernel_regularizer=kernel_regularizer,
        )(conv1)
        return _shortcut3d(input, residual)

    return f

def _handle_data_format():
    global DIM1_AXIS
    global DIM2_AXIS
    global DIM3_AXIS
    global CHANNEL_AXIS
    if K.image_data_format() == "channels_last":
        DIM1_AXIS = 1
        DIM2_AXIS = 2
        DIM3_AXIS = 3
        CHANNEL_AXIS = 4
    else:
        CHANNEL_AXIS = 1
        DIM1_AXIS = 2
        DIM2_AXIS = 3
        DIM3_AXIS = 4

def _get_block(identifier):
    if isinstance(identifier, six.string_types):
        res = globals().get(identifier)
        if not res:
            raise ValueError("Invalid {}".format(identifier))
        return res
    return identifier

class Resnet3DBuilder(object):
    """ResNet3D."""

    @staticmethod
    def build(input_shape, num_outputs, block_fn, repetitions, reg_factor):
        """Instantiate a vanilla ResNet3D keras model.

        # Arguments
            input_shape: Tuple of input shape in the format
            (conv_dim1, conv_dim2, conv_dim3, channels) if dim_ordering='tf'
            (filter, conv_dim1, conv_dim2, conv_dim3) if dim_ordering='th'
            num_outputs: The number of outputs at the final softmax layer
            block_fn: Unit block to use {'basic_block', 'bottlenack_block'}
            repetitions: Repetitions of unit blocks
        # Returns
            model: a 3D ResNet model that takes a 5D tensor (volumetric images
            in batch) as input and returns a 1D vector (prediction) as output.
        """
        _handle_data_format()
        if len(input_shape) != 4:
            raise ValueError(
                "Input shape should be a tuple "
                "(conv_dim1, conv_dim2, conv_dim3, channels) "
                "for tensorflow as backend or "
                "(channels, conv_dim1, conv_dim2, conv_dim3) "
                "for theano as backend"
            )

        block_fn = _get_block(block_fn)
        input = Input(shape=input_shape)
        # first conv
        conv1 = _conv_bn_relu3D(
            filters=128,  # Changed filter size
            kernel_size=(5, 5, 5),  # Changed kernel size
            strides=(2, 2, 2),
            kernel_regularizer=l2(reg_factor),
        )(input)
        pool1 = MaxPooling3D(pool_size=(3, 3, 3), strides=(2, 2, 2), padding="same")(
            conv1
        )

        # repeat blocks
        block = pool1
        filters = 128  # Changed filter size
        for i, r in enumerate(repetitions):
            block = _residual_block_with_cbam(
                filters=filters,
                kernel_regularizer=l2(reg_factor),
                is_first_layer=(i == 0),
            )(block)
            filters *= 2

        # last activation
        block_output = _bn_relu(block)

        # average pool and classification
        pool2 = AveragePooling3D(
            pool_size=(
                block.shape[DIM1_AXIS],
                block.shape[DIM2_AXIS],
                block.shape[DIM3_AXIS],
            ),
            strides=(1, 1, 1),
        )(block_output)
        flatten1 = Flatten()(pool2)
        if num_outputs > 1:
            dense = Dense(
                units=num_outputs,
                kernel_initializer="he_normal",
                activation="softmax",
                kernel_regularizer=l2(reg_factor),
            )(flatten1)
        else:
            dense = Dense(
                units=num_outputs,
                kernel_initializer="he_normal",
                activation="sigmoid",
                kernel_regularizer=l2(reg_factor),
            )(flatten1)

        model = Model(inputs=input, outputs=dense)
        return model



    @staticmethod
    def build_resnet_152(input_shape, num_outputs, reg_factor=1e-4):
        """Build resnet 152."""
        return Resnet3DBuilder.build(
            input_shape, num_outputs, basic_block, [3, 16, 36, 6], reg_factor=reg_factor
        )

# %%
# Testing the model
def apply_mask(aseg_image, brain_image, labels = [17, 53, 2, 7, 41, 46]):
    brain_data = aseg_image.get_fdata()
    aseg_data = aseg_image.get_fdata()
    origin_data = brain_image.get_fdata()
    
    brain_mask = np.zeros_like(aseg_data)
    for label in labels:
        brain_mask += np.where((aseg_data == label), 1, 0)

    new_image = origin_data * brain_mask
    
    return new_image

# %%
def enhance_slice(slice_data):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_slice = clahe.apply(slice_data.astype(np.uint8))

    return enhanced_slice

def enhance_image(img_data):
    enhanced_image = np.zeros_like(img_data)
    for i in range(img_data.shape[2]):
        enhanced_image[:, :, i] = enhance_slice(img_data[:, :, i])
    return enhanced_image

# %%
def sharpen_image(image, strength=1.0):
    sharpened_image = unsharp_mask(image, radius=1, amount=strength)
    return sharpened_image

def apply_nonlinear_registration(moving_image, fixed_image):
    metric = CCMetric(3)

    sdr = SymmetricDiffeomorphicRegistration(metric, [10, 10, 10], step_length=0.25, ss_sigma_factor=1.5)

    mapping = sdr.optimize(fixed_image, moving_image)

    warped_moving_image = mapping.transform(moving_image)

    return warped_moving_image

# %%
def image_fixed(image_type, target_shape):
    aseg_image = nibabel.load('/home/uiu/Documents/oasis_fastsurfer/dataset/AD/OAS1_0028_MR1_1')
    base_path = "/home/uiu/Documents/oasis_fastsurfer/dataset/AD/OAS1_0028_MR1_1/mri/orig.mgz"
    origin_image =  nibabel.load(base_path)
    
    if (image_type == 'roi') :
        image = apply_mask(aseg_image, origin_image)
        image = resize(image, target_shape, anti_aliasing=True)
        image = sharpen_image(image)
        return image

# %%
from scipy.ndimage import rotate

# %%
def augment(image, rotation_range):
    rotation_angle = np.random.uniform(-rotation_range, rotation_range)
    rotated_image = rotate(image, rotation_angle, reshape=False)
    
    return rotated_image



def image_loader_roi(image_path, target_shape, type_dt=''):
    aseg_image = nibabel.load(image_path)
    base_path = "/".join(image_path.split('/')[:-1]) + "/orig.mgz"
    base_image =  nibabel.load(base_path)
    
    image = apply_mask(aseg_image, base_image)
    image = resize(image, target_shape, anti_aliasing=True)
    image = enhance_image(image)
    image = sharpen_image(image)
    
    if type_dt=='train':
        image = augment(image, 50)

    return image

# %%
def data_generator(paths, labels, batch_size, target_shape, image_type, type_dt=''):
    while True:
        for i in range(0, len(paths), batch_size):
            batch_paths = paths[i:i+batch_size]
            batch_labels = labels[i:i+batch_size]
            batch_images = []
            
    
            if image_type == 'roi':
                batch_images = [image_loader_roi(image, target_shape, type_dt) for image in batch_paths]


            batch_images = np.stack([batch_images] * 1, axis=-1)

            batch_labels = to_categorical(batch_labels, num_classes=2)
            yield np.array(batch_images), batch_labels
base_dir = '/home/uiu/Documents/oasis_fastsurfer/dataset'
ad = os.path.join(base_dir, 'AD')
mci = os.path.join(base_dir, 'MCI')
cn = os.path.join(base_dir, 'CN')
# original shape (257, 257, 257)

ad_images= []
mci_images = []
cn_images = []

for subject_dir in os.listdir(ad):
    mri_path = os.path.join(ad, subject_dir, 'mri', 'aparc.DKTatlas+aseg.deep.mgz')
    if not (len(os.listdir(os.path.join(ad, subject_dir, 'mri'))) < 6):
        ad_images.append(mri_path)
        
for subject_dir in os.listdir(mci):
    mri_path = os.path.join(mci, subject_dir, 'mri', 'aparc.DKTatlas+aseg.deep.mgz')
    
    if not (len(os.listdir(os.path.join(mci, subject_dir, 'mri'))) < 6):
        mci_images.append(mri_path)
        
for subject_dir in os.listdir(cn):
    mri_path = os.path.join(cn, subject_dir, 'mri', 'aparc.DKTatlas+aseg.deep.mgz')
    if not (len(os.listdir(os.path.join(cn, subject_dir, 'mri'))) < 6):
        cn_images.append(mri_path)


image_path = mci_images + cn_images + cn_images[:len(mci_images)-len(cn_images)]
labels = [0] * len(mci_images) + [1] * len(cn_images) + [1] * len(cn_images[:len(mci_images)-len(cn_images)])
train_paths, test_paths, train_labels, test_labels = train_test_split(image_path, labels, test_size = 0.2, random_state=42)

class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
train_paths = np.array(train_paths)
train_labels = np.array(train_labels)
test_paths = np.array(test_paths)
test_labels = np.array(test_labels)

train_paths, train_labels = shuffle(train_paths, train_labels, random_state=42)
test_paths, test_labels = shuffle(test_paths, test_labels, random_state=42)

target_shape = (100, 100, 100)
batch_size = 10
selection_type = 'roi'
train_dataset = data_generator(train_paths, train_labels, batch_size, target_shape, 
                               image_type=selection_type, 
                               type_dt='train'
                              )

test_dataset = data_generator(test_paths, test_labels, batch_size, target_shape, 
                              image_type=selection_type
                             )
len(test_paths), len(train_labels), class_weights
# Out:
# (369, 1472, array([3.33031674, 0.58832934]))

# %%
from tensorflow.keras.optimizers import Adam

# %%
classes = 2
image_shape = (*target_shape, 1)
model = Resnet3DBuilder.build_resnet_152(input_shape = image_shape, num_outputs=classes)

model.compile(
    optimizer=Adam(0.00001), 
    loss='binary_crossentropy', 
    metrics=['accuracy', 'Recall', 'AUC', 'Precision'] 
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 10 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 50, 50, 50, 1 16128       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 50, 50, 1 512         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 50, 50, 50, 1 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 25, 25, 25, 1 0           activation[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 25, 25, 25, 1 2048128     max_pooling3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 25, 25, 25, 1 512         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 25, 25, 25, 1 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 25, 25, 25, 1 2048128     activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 25, 1 512         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 25, 25, 25, 1 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d (Globa (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d (GlobalMax (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        global_average_pooling3d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        global_max_pooling3d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64)           0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          8320        add[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1, 128) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 25, 25, 25, 1 129         activation_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 25, 25, 25, 1 0           activation_2[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 25, 25, 25, 1 0           activation_2[0][0]
#                                                                  conv3d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 25, 25, 25, 1 0           multiply[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 25, 25, 25, 1 0           max_pooling3d[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 13, 13, 13, 2 4096256     add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 13, 13, 13, 2 1024        conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 13, 13, 13, 2 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 13, 13, 13, 2 8192256     activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 13, 13, 13, 2 1024        conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 13, 13, 13, 2 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_1 (Glo (None, 256)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_1 (GlobalM (None, 256)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          32896       global_average_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          32896       global_max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128)          0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          33024       add_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 1, 256) 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 13, 13, 13, 1 257         activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 13, 13, 13, 2 0           activation_5[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 13, 13, 13, 2 0           activation_5[0][0]
#                                                                  conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 13, 13, 13, 2 33024       add_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 13, 13, 13, 2 0           multiply_2[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 13, 13, 13, 2 0           conv3d_7[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 7, 7, 7, 512) 16384512    add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 7, 7, 7, 512) 2048        conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 7, 512) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 7, 7, 7, 512) 32768512    activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 7, 512) 2048        conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 7, 512) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_2 (Glo (None, 512)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_2 (GlobalM (None, 512)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      global_average_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          131328      global_max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256)          0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          131584      add_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 1, 512) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 7, 7, 7, 1)   513         activation_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 7, 7, 7, 512) 0           activation_8[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 7, 7, 7, 512) 0           activation_8[0][0]
#                                                                  conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 7, 7, 7, 512) 131584      add_5[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 7, 512) 0           multiply_4[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 7, 512) 0           conv3d_11[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, 4, 4, 1024 65537024    add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 4, 1024 4096        conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 4, 1024 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 4, 4, 4, 1024 131073024   activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 4, 1024 4096        conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 4, 1024 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_3 (Glo (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_3 (GlobalM (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          524800      global_average_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 512)          524800      global_max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 512)          0           dense_9[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1024)         525312      add_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1024)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 1, 1024 0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 4, 4, 4, 1)   1025        activation_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 4, 4, 4, 1024 0           activation_11[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 4, 4, 4, 1024 0           activation_11[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 4, 4, 4, 1024 525312      add_8[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 4, 1024 0           multiply_6[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 4, 1024 0           conv3d_15[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 4, 1024 4096        add_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 4, 1024 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling3d (AveragePooli (None, 1, 1, 1, 1024 0           activation_13[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling3d[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            2050        flatten[0][0]
# ==================================================================================================
# Total params: 264,970,630
# Trainable params: 264,960,646
# Non-trainable params: 9,984
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model_checkpoint = ModelCheckpoint('Upgrade_Filter_6ROI_OASIS_MCIvsCN.h5', monitor='val_accuracy', mode='max', save_best_only=True)

num_epoch = 50
history = model.fit(
    train_dataset,
    epochs=num_epoch,
    steps_per_epoch=len(train_paths) // batch_size,
    validation_data=test_dataset,
    validation_steps=len(test_paths) // batch_size,
    callbacks=[model_checkpoint]  
)
# Out:
# Epoch 1/50
# 147/147 [==============================] - 1889s 13s/step - loss: 1.6480 - accuracy: 0.7995 - recall: 0.7995 - auc: 0.8433 - precision: 0.7995 - val_loss: 1.5231 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9076 - val_precision: 0.8639
# Epoch 2/50
# 147/147 [==============================] - 1924s 13s/step - loss: 1.5563 - accuracy: 0.8313 - recall: 0.8313 - auc: 0.8829 - precision: 0.8313 - val_loss: 1.4779 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.9312 - val_precision: 0.8639
# Epoch 3/50
# 147/147 [==============================] - 1892s 13s/step - loss: 1.5061 - accuracy: 0.8317 - recall: 0.8317 - auc: 0.9046 - precision: 0.8317 - val_loss: 1.8026 - val_accuracy: 0.5250 - val_recall: 0.5250 - val_auc: 0.5449 - val_precision: 0.5250
# Epoch 4/50
# 147/147 [==============================] - 1907s 13s/step - loss: 1.4423 - accuracy: 0.8406 - recall: 0.8406 - auc: 0.9275 - precision: 0.8406 - val_loss: 2.1561 - val_accuracy: 0.1389 - val_recall: 0.1389 - val_auc: 0.2154 - val_precision: 0.1389
# Epoch 5/50
# 147/147 [==============================] - 1871s 13s/step - loss: 1.4119 - accuracy: 0.8425 - recall: 0.8425 - auc: 0.9318 - precision: 0.8425 - val_loss: 1.9614 - val_accuracy: 0.3250 - val_recall: 0.3250 - val_auc: 0.3210 - val_precision: 0.3250
# Epoch 6/50
# 147/147 [==============================] - 1860s 13s/step - loss: 1.3634 - accuracy: 0.8642 - recall: 0.8642 - auc: 0.9435 - precision: 0.8642 - val_loss: 1.9617 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 7/50
# 147/147 [==============================] - 1851s 13s/step - loss: 1.3236 - accuracy: 0.8683 - recall: 0.8683 - auc: 0.9553 - precision: 0.8683 - val_loss: 1.3136 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.9512 - val_precision: 0.8694
# Epoch 8/50
# 147/147 [==============================] - 1859s 13s/step - loss: 1.2899 - accuracy: 0.8906 - recall: 0.8906 - auc: 0.9603 - precision: 0.8906 - val_loss: 2.5201 - val_accuracy: 0.1611 - val_recall: 0.1611 - val_auc: 0.2308 - val_precision: 0.1611
# Epoch 9/50
# 147/147 [==============================] - 1852s 13s/step - loss: 1.2704 - accuracy: 0.8890 - recall: 0.8890 - auc: 0.9616 - precision: 0.8890 - val_loss: 1.9437 - val_accuracy: 0.4250 - val_recall: 0.4250 - val_auc: 0.4324 - val_precision: 0.4250
# Epoch 10/50
# 147/147 [==============================] - 1859s 13s/step - loss: 1.2275 - accuracy: 0.8985 - recall: 0.8985 - auc: 0.9714 - precision: 0.8985 - val_loss: 1.2386 - val_accuracy: 0.8889 - val_recall: 0.8889 - val_auc: 0.9679 - val_precision: 0.8889
# Epoch 11/50
# 147/147 [==============================] - 1903s 13s/step - loss: 1.2176 - accuracy: 0.8962 - recall: 0.8962 - auc: 0.9689 - precision: 0.8962 - val_loss: 1.2174 - val_accuracy: 0.9000 - val_recall: 0.9000 - val_auc: 0.9640 - val_precision: 0.9000
# Epoch 12/50
# 147/147 [==============================] - 1896s 13s/step - loss: 1.1882 - accuracy: 0.9152 - recall: 0.9152 - auc: 0.9750 - precision: 0.9152 - val_loss: 1.8631 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 13/50
# 147/147 [==============================] - 1875s 13s/step - loss: 1.1617 - accuracy: 0.9248 - recall: 0.9248 - auc: 0.9784 - precision: 0.9248 - val_loss: 1.4722 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8968 - val_precision: 0.8639
# Epoch 14/50
# 147/147 [==============================] - 1871s 13s/step - loss: 1.1559 - accuracy: 0.9264 - recall: 0.9264 - auc: 0.9726 - precision: 0.9264 - val_loss: 1.4579 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8900 - val_precision: 0.8639
# Epoch 15/50
# 147/147 [==============================] - 1858s 13s/step - loss: 1.1268 - accuracy: 0.9409 - recall: 0.9409 - auc: 0.9791 - precision: 0.9409 - val_loss: 1.5772 - val_accuracy: 0.6722 - val_recall: 0.6722 - val_auc: 0.7360 - val_precision: 0.6722
# Epoch 16/50
# 147/147 [==============================] - 1860s 13s/step - loss: 1.1058 - accuracy: 0.9366 - recall: 0.9366 - auc: 0.9807 - precision: 0.9366 - val_loss: 1.2699 - val_accuracy: 0.8750 - val_recall: 0.8750 - val_auc: 0.9359 - val_precision: 0.8750
# Epoch 17/50
# 147/147 [==============================] - 1863s 13s/step - loss: 1.0848 - accuracy: 0.9463 - recall: 0.9463 - auc: 0.9836 - precision: 0.9463 - val_loss: 3.5350 - val_accuracy: 0.1667 - val_recall: 0.1667 - val_auc: 0.1879 - val_precision: 0.1667
# Epoch 18/50
# 147/147 [==============================] - 1853s 13s/step - loss: 1.0582 - accuracy: 0.9549 - recall: 0.9549 - auc: 0.9880 - precision: 0.9549 - val_loss: 1.1708 - val_accuracy: 0.8944 - val_recall: 0.8944 - val_auc: 0.9533 - val_precision: 0.8944
# Epoch 19/50
# 147/147 [==============================] - 1843s 13s/step - loss: 1.0375 - accuracy: 0.9579 - recall: 0.9579 - auc: 0.9883 - precision: 0.9579 - val_loss: 2.0880 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 20/50
# 147/147 [==============================] - 1857s 13s/step - loss: 1.0275 - accuracy: 0.9572 - recall: 0.9572 - auc: 0.9879 - precision: 0.9572 - val_loss: 2.0439 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 21/50
# 147/147 [==============================] - 1818s 12s/step - loss: 1.0157 - accuracy: 0.9561 - recall: 0.9561 - auc: 0.9886 - precision: 0.9561 - val_loss: 1.3103 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.9119 - val_precision: 0.8694
# Epoch 22/50
# 147/147 [==============================] - 1795s 12s/step - loss: 1.0026 - accuracy: 0.9564 - recall: 0.9564 - auc: 0.9899 - precision: 0.9564 - val_loss: 1.5751 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8711 - val_precision: 0.8639
# Epoch 23/50
# 147/147 [==============================] - 1799s 12s/step - loss: 1.0018 - accuracy: 0.9573 - recall: 0.9573 - auc: 0.9863 - precision: 0.9573 - val_loss: 1.1236 - val_accuracy: 0.9000 - val_recall: 0.9000 - val_auc: 0.9617 - val_precision: 0.9000
# Epoch 24/50
# 147/147 [==============================] - 1794s 12s/step - loss: 0.9578 - accuracy: 0.9697 - recall: 0.9697 - auc: 0.9947 - precision: 0.9697 - val_loss: 1.1144 - val_accuracy: 0.8972 - val_recall: 0.8972 - val_auc: 0.9581 - val_precision: 0.8972
# Epoch 25/50
# 147/147 [==============================] - 1799s 12s/step - loss: 0.9637 - accuracy: 0.9601 - recall: 0.9601 - auc: 0.9871 - precision: 0.9601 - val_loss: 1.8571 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 26/50
# 147/147 [==============================] - 1810s 12s/step - loss: 0.9517 - accuracy: 0.9634 - recall: 0.9634 - auc: 0.9911 - precision: 0.9634 - val_loss: 0.9204 - val_accuracy: 0.9806 - val_recall: 0.9806 - val_auc: 0.9956 - val_precision: 0.9806
# Epoch 27/50
# 147/147 [==============================] - 1846s 13s/step - loss: 0.9641 - accuracy: 0.9646 - recall: 0.9646 - auc: 0.9856 - precision: 0.9646 - val_loss: 2.0375 - val_accuracy: 0.5306 - val_recall: 0.5306 - val_auc: 0.5332 - val_precision: 0.5306
# Epoch 28/50
# 147/147 [==============================] - 1834s 13s/step - loss: 0.9199 - accuracy: 0.9776 - recall: 0.9776 - auc: 0.9923 - precision: 0.9776 - val_loss: 0.9101 - val_accuracy: 0.9694 - val_recall: 0.9694 - val_auc: 0.9977 - val_precision: 0.9694
# Epoch 29/50
# 147/147 [==============================] - 1822s 12s/step - loss: 0.9249 - accuracy: 0.9677 - recall: 0.9677 - auc: 0.9884 - precision: 0.9677 - val_loss: 2.8121 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 30/50
# 147/147 [==============================] - 1820s 12s/step - loss: 0.9199 - accuracy: 0.9705 - recall: 0.9705 - auc: 0.9919 - precision: 0.9705 - val_loss: 1.9729 - val_accuracy: 0.5972 - val_recall: 0.5972 - val_auc: 0.6040 - val_precision: 0.5972
# Epoch 31/50
# 147/147 [==============================] - 1810s 12s/step - loss: 0.9029 - accuracy: 0.9666 - recall: 0.9666 - auc: 0.9918 - precision: 0.9666 - val_loss: 0.9512 - val_accuracy: 0.9528 - val_recall: 0.9528 - val_auc: 0.9879 - val_precision: 0.9528
# Epoch 32/50
# 147/147 [==============================] - 1808s 12s/step - loss: 0.8977 - accuracy: 0.9735 - recall: 0.9735 - auc: 0.9895 - precision: 0.9735 - val_loss: 1.8806 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 33/50
# 147/147 [==============================] - 1814s 12s/step - loss: 0.8637 - accuracy: 0.9808 - recall: 0.9808 - auc: 0.9956 - precision: 0.9808 - val_loss: 1.1967 - val_accuracy: 0.8111 - val_recall: 0.8111 - val_auc: 0.8979 - val_precision: 0.8111
# Epoch 34/50
# 147/147 [==============================] - 1829s 13s/step - loss: 0.8700 - accuracy: 0.9737 - recall: 0.9737 - auc: 0.9937 - precision: 0.9737 - val_loss: 2.1717 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 35/50
# 147/147 [==============================] - 1806s 12s/step - loss: 0.8402 - accuracy: 0.9864 - recall: 0.9864 - auc: 0.9958 - precision: 0.9864 - val_loss: 1.4007 - val_accuracy: 0.8667 - val_recall: 0.8667 - val_auc: 0.8783 - val_precision: 0.8667
# Epoch 36/50
# 147/147 [==============================] - 1814s 12s/step - loss: 0.8425 - accuracy: 0.9825 - recall: 0.9825 - auc: 0.9946 - precision: 0.9825 - val_loss: 1.2871 - val_accuracy: 0.8750 - val_recall: 0.8750 - val_auc: 0.8977 - val_precision: 0.8750
# Epoch 37/50
# 147/147 [==============================] - 1810s 12s/step - loss: 0.8176 - accuracy: 0.9868 - recall: 0.9868 - auc: 0.9991 - precision: 0.9868 - val_loss: 1.1022 - val_accuracy: 0.8417 - val_recall: 0.8417 - val_auc: 0.9276 - val_precision: 0.8417
# Epoch 38/50
# 147/147 [==============================] - 1813s 12s/step - loss: 0.8241 - accuracy: 0.9798 - recall: 0.9798 - auc: 0.9957 - precision: 0.9798 - val_loss: 0.8719 - val_accuracy: 0.9472 - val_recall: 0.9472 - val_auc: 0.9875 - val_precision: 0.9472
# Epoch 39/50
# 147/147 [==============================] - 1797s 12s/step - loss: 0.8222 - accuracy: 0.9758 - recall: 0.9758 - auc: 0.9964 - precision: 0.9758 - val_loss: 1.9250 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 40/50
# 147/147 [==============================] - 1821s 12s/step - loss: 0.8090 - accuracy: 0.9789 - recall: 0.9789 - auc: 0.9972 - precision: 0.9789 - val_loss: 0.8023 - val_accuracy: 0.9806 - val_recall: 0.9806 - val_auc: 0.9935 - val_precision: 0.9806
# Epoch 41/50
# 147/147 [==============================] - 1818s 12s/step - loss: 0.7970 - accuracy: 0.9805 - recall: 0.9805 - auc: 0.9966 - precision: 0.9805 - val_loss: 2.0738 - val_accuracy: 0.5306 - val_recall: 0.5306 - val_auc: 0.5477 - val_precision: 0.5306
# Epoch 42/50
# 147/147 [==============================] - 1830s 13s/step - loss: 0.7868 - accuracy: 0.9838 - recall: 0.9838 - auc: 0.9970 - precision: 0.9838 - val_loss: 1.2377 - val_accuracy: 0.8694 - val_recall: 0.8694 - val_auc: 0.8951 - val_precision: 0.8694
# Epoch 43/50
# 147/147 [==============================] - 1833s 13s/step - loss: 0.7888 - accuracy: 0.9798 - recall: 0.9798 - auc: 0.9979 - precision: 0.9798 - val_loss: 0.9035 - val_accuracy: 0.9361 - val_recall: 0.9361 - val_auc: 0.9698 - val_precision: 0.9361
# Epoch 44/50
# 147/147 [==============================] - 1833s 13s/step - loss: 0.7738 - accuracy: 0.9848 - recall: 0.9848 - auc: 0.9980 - precision: 0.9848 - val_loss: 2.9191 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8639 - val_precision: 0.8639
# Epoch 45/50
# 147/147 [==============================] - 1858s 13s/step - loss: 0.7740 - accuracy: 0.9846 - recall: 0.9846 - auc: 0.9968 - precision: 0.9846 - val_loss: 1.8355 - val_accuracy: 0.8639 - val_recall: 0.8639 - val_auc: 0.8663 - val_precision: 0.8639
# Epoch 46/50
# 147/147 [==============================] - 1844s 13s/step - loss: 0.7696 - accuracy: 0.9871 - recall: 0.9871 - auc: 0.9973 - precision: 0.9871 - val_loss: 2.8968 - val_accuracy: 0.2861 - val_recall: 0.2861 - val_auc: 0.2750 - val_precision: 0.2861
# Epoch 47/50
# 147/147 [==============================] - 1849s 13s/step - loss: 0.7548 - accuracy: 0.9904 - recall: 0.9904 - auc: 0.9959 - precision: 0.9904 - val_loss: 1.0805 - val_accuracy: 0.9000 - val_recall: 0.9000 - val_auc: 0.9236 - val_precision: 0.9000
# Epoch 48/50
# 147/147 [==============================] - 1839s 13s/step - loss: 0.7611 - accuracy: 0.9817 - recall: 0.9817 - auc: 0.9968 - precision: 0.9817 - val_loss: 3.6434 - val_accuracy: 0.2528 - val_recall: 0.2528 - val_auc: 0.2294 - val_precision: 0.2528
# Epoch 49/50
# 147/147 [==============================] - 1816s 12s/step - loss: 0.7404 - accuracy: 0.9871 - recall: 0.9871 - auc: 0.9988 - precision: 0.9871 - val_loss: 0.8850 - val_accuracy: 0.9194 - val_recall: 0.9194 - val_auc: 0.9733 - val_precision: 0.9194
# Epoch 50/50
# 147/147 [==============================] - 1821s 12s/step - loss: 0.7345 - accuracy: 0.9907 - recall: 0.9907 - auc: 0.9972 - precision: 0.9907 - val_loss: 0.8136 - val_accuracy: 0.9556 - val_recall: 0.9556 - val_auc: 0.9859 - val_precision: 0.9556

# %%
saved_model = tf.keras.models.load_model('Upgrade_Filter_6ROI_OASIS_MCIvsCN.h5')
test_accuracy = saved_model.evaluate(
    test_dataset,
    steps=len(test_paths) // batch_size,
    verbose=1
)
print("Test Accuracy:", test_accuracy)
# Out:
# 36/36 [==============================] - 325s 9s/step - loss: 0.9204 - accuracy: 0.9806 - recall: 0.9806 - auc: 0.9956 - precision: 0.9806
# Test Accuracy: [0.9203713536262512, 0.980555534362793, 0.980555534362793, 0.9955554604530334, 0.980555534362793]

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('UpgradedFilter_ROI_OASIS')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')


plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig("UpgradedFilter_ROI_OASIS.png")

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model('Upgrade_Filter_6ROI_OASIS_MCIvsCN.h5')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
# Load the saved model
saved_model = tf.keras.models.load_model('Upgrade_Filter_6ROI_OASIS_MCIvsCN.h5')

# %%
predictions = saved_model.predict(test_dataset, steps=len(test_paths) // batch_size)
predicted_labels = np.argmax(predictions, axis=1)


conf_matrix = confusion_matrix(test_labels[:len(predicted_labels)], predicted_labels)


plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', 
            xticklabels=['MCI', 'CN'], yticklabels=['MCI', 'CN'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Region of Interests')
plt.savefig('confusion_matrix_6ROI.png')


plt.show()
